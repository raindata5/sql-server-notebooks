-- %% [markdown]
-- EX 3-3

-- %%
SELECT SalesOrderID, OrderDate, TotalDue
FROM Sales.SalesOrderHeader
WHERE OrderDate >= '2012-09-01' AND OrderDate < '2012-10-01'
AND TotalDue >= 10000 OR SalesOrderID < 43000 ;
-- Out:
-- (66 rows affected)
-- Total execution time: 00:00:00.024
-- ...

-- %%
USE WideWorldImporters
GO
SELECT *
FROM Application.StateProvinces
WHERE StateProvinceID /* IN (1,45) */ = 1 or StateProvinceID = 45;
-- Out:
-- Commands completed successfully.
-- (2 rows affected)
-- Total execution time: 00:00:00.228
-- <table><tr><th>StateProvinceID</th><th>StateProvinceCode</th><th>StateProvinceName</th><th>CountryID</th><th>SalesTerritory</th><th>Border</th><th>LatestRecordedPopulation</th><th>LastEditedBy</th><th>ValidFrom</th><th>ValidTo</th></tr><tr><td>1</td><td>AL</td><td>Alabama</td><td>230</td><td>Southeast</td><td>...</td><td>5437278</td><td>15</td><td>2015-07-01 16:00:00.0000000</td><td>9999-12-31 23:59:59.9999999</td></tr><tr><td>45</td><td>TX</td><td>Texas</td><td>230</td><td>Southwest</td><td>...</td><td>27506120</td><td>20</td><td>2013-07-01 16:00:00.0000000</td><td>9999-12-31 23:59:59.9999999</td></tr></table>

-- %% [markdown]
-- 3-4

-- %%
select ProductID,Name,Color
FROM AdventureWorks2019.Production.Product
WHERE color IS NULL ;
-- Out:
-- (248 rows affected)
-- Total execution time: 00:00:00.008
-- ...

-- %%
select ProductID,Name,Style,[Size],Color
FROM AdventureWorks2019.Production.Product
WHERE color IS NOT NULL OR [Size] IS NOT NULL ;
-- Out:
-- (256 rows affected)
-- Total execution time: 00:00:00.022
-- ...

-- %%
USE WideWorldImporters
GO
SELECT *
FROM Purchasing.Suppliers
WHERE DeliveryMethodID IS NULL ;
-- Out:
-- Commands completed successfully.
-- (4 rows affected)
-- Total execution time: 00:00:00.277
-- ...

-- %%
-- Out:
-- : Msg 208, Level 16, State 1, Line 1
-- Invalid object name 'Purchasing.Supplier'.
-- Total execution time: 00:00:00.003
